# %%
import numpy as np
import pandas as pd

# %%
d = pd.DataFrame(
[
    [1, 2, 3, 4, 5],
    [4, 5, 6, 7, 8]    
],
    index = [2, 3],
    columns = ['a', 'b', 'c', 'd', 'e']
)
d
# Out:
#    a  b  c  d  e
# 2  1  2  3  4  5
# 3  4  5  6  7  8

# %%
k = pd.DataFrame(
    np.random.randint(0, 10, (6, 4)), # 服从（0， 1）正态分布
    index = [1, 2, 3, 4, 5, 6],
    columns = ['a', 'b', 'c', 'd']
)
k
# Out:
#    a  b  c  d
# 1  8  1  5  2
# 2  5  1  2  3
# 3  5  8  6  5
# 4  1  4  0  2
# 5  9  4  7  4
# 6  8  0  1  0

# %%
k['b'].isin([1])
# Out:
# 1     True
# 2     True
# 3    False
# 4    False
# 5    False
# 6    False
# Name: b, dtype: bool

# %%
liang = pd.read_excel('李文杰18.11.12整理-国内差旅_1-.xls', sheet_name='梁教授')
liang
# Out:
#          序号               差旅时间                       旅途       交通  \
# 0         1   2016.05.05-05.12              广州-成都-北京-广州    广州-成都
# 1       NaN                NaN                      NaN    成都-北京
# 2       NaN                NaN                      NaN    北京-广州
# 3         2   2016.09.07-09.11                 广州-深圳-广州     情况说明
# 4       NaN                NaN                      NaN      NaN
# 5         3   2016.09.16-09.17                 广州-深圳-广州    广州-深圳
# 6       NaN                NaN                      NaN    深圳-广州
# 7         4   2016.09.27-10.07                 广州-成都-广州    广州-成都
# 8       NaN                NaN                      NaN   成都-广州
# 9       NaN                NaN                      NaN      NaN
# 10        5   2016.10.11-10.18              广州-南京-深圳-广州    广州-南京
# 11      NaN                NaN                      NaN    南京-深圳
# 12      NaN                NaN                      NaN    深圳-广州
# ...

# %%
liang['总额'].sum()
# Out:
# 161211.5

# %%
liang2 =  pd.read_excel('李文杰18.11.12整理-国内差旅_1-.xls', sheet_name='Sheet1')

# %%
liang2['总额'].sum()
# Out:
# 51752.5

# %%
table = pd.read_html('住房统计.htm')
table
# Out:
# [    0        1
#  0 NaN  检索 | 高级,
#           0         1          2       3         4          5      6      7
#  0       城市        环比         同比      定基        城市         环比     同比     定基
#  1   上月=100  上年同月=100  2015年=100  上月=100  上年同月=100  2015年=100    NaN    NaN
#  2      北 京     100.2      100.8   135.9       唐 山      101.2  112.9  121.1
#  3      天 津     100.1      101.9   131.1     秦 皇 岛      102.1  115.0  127.9
#  4    石 家 庄     103.3      110.7   136.8       包 头      101.4  113.1  115.8
#  5      太 原     100.5      109.8   121.7       丹 东      100.4  116.2  115.7
#  6     呼和浩特     101.6      117.6   123.8       锦 州      101.4  108.7  105.7
#  7      沈 阳     101.5      112.7   128.0       吉 林      101.5  111.0  119.6
#  8      大 连     100.7      113.8   123.4     牡 丹 江      101.7  112.2  115.0
#  9      长 春     100.9      110.6   122.3       无 锡      100.4  104.4  139.8
#  10   哈 尔 滨     102.0      114.3   128.1       扬 州      101.2  111.2  133.2
# ...

# %%
# 输出单个表格
table[0]
table[1]
table[6]
# Out:
#          0         1          2        3         4          5       6  \
# 0       城市   90m2及以下   90-144m2  144m2以上       NaN        NaN     NaN
# 1       环比        同比         定基       环比        同比         定基      环比
# 2   上月=100  上年同月=100  2015年=100   上月=100  上年同月=100  2015年=100  上月=100
# 3      唐 山     100.8      107.1    113.8     101.2      105.0   110.2
# 4    秦 皇 岛     100.5      108.0    118.8     100.9      109.1   118.4
# 5      包 头     100.1      104.6    104.0     100.2      107.0   108.7
# 6      丹 东     100.0      105.9    105.0     100.1      107.3   109.3
# 7      锦 州     100.0      105.0     98.4     101.0      103.9    96.7
# 8      吉 林     100.5      107.1    112.4     100.4      107.3   113.0
# 9    牡 丹 江     100.7      105.1    109.9     100.8      106.0   106.4
# 10     无 锡      99.9      105.6    138.4     100.1      105.5   136.2
# 11     扬 州     101.4      109.3    123.6     101.3      108.2   121.0
# ...
